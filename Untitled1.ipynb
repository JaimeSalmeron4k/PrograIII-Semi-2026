# %% [markdown]
# <a href="https://colab.research.google.com/github/JaimeSalmeron4k/PrograIII-Semi-2026/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print ("Hello World")
a = 6
b = 7
c = a + b
print(c)
# Out:
# Hello World
# 13

# %%
saludo = "Hola chicos de progra III"
print(saludo, "Primera letra del saludo", saludo[0:4])

num1 = 5.25
print(num1)
# Out:
# Hola chicos de progra III Primera letra del saludo Hola
# 5.25

# %%
print("Sumar dos numeros : ")
num1 = input("Num1: ")
num2 = input("Num2: ")
respuesta = float(num1) + float(num2)

print(type(num1), type(num2), type (respuesta))

print("Respuesta: ", respuesta)

respuesta = "Suma completa"
print(respuesta, type (respuesta))
# Out:
# Sumar dos numeros :
# Num1: 4.6
# Num2: 2.2
# <class 'str'> <class 'str'> <class 'float'>
# Respuesta:  6.8
# Suma completa

# %%
print("Resta de dos numeros")
num1 = input("Num1: ")
num2 = input("Num2: ")
respuesta = float(num1) - float(num2)

print("Respuesta: ", respuesta)

respuesta = "Resta completa"
print(respuesta)
# Out:
# Resta de dos numeros
# Num1: 8
# Num2: 3.5
# Respuesta:  4.5
# Resta completa

# %%
print("Multiplicacion de dos numeros")
num1 = input("Num1: ")
num2 = input("Num2: ")
respuesta = float(num1) * float(num2)

print("Respuesta: ", respuesta)

respuesta = "Multiplicacion completada"
print(respuesta)
# Out:
# Multiplicacion de dos numeros
# Num1: 5
# Num2: 4
# Respuesta:  20.0
# Multiplicacion completada

# %%
print("Division de dos numeros")
num1 = input("Num1: ")
num2 = input("Num2: ")
respuesta = float(num1) / float(num2)


print("Respuesta: ", respuesta)

respuesta = "Division completa"
print(respuesta)
# Out:
# Division de dos numeros
# Num1: 9.4
# Num2: 3.6
# Respuesta:  2.611111111111111
# Division completa
